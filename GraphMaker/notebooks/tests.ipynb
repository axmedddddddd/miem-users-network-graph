# %%
from typing import TypeVar
import sqlalchemy as sa
from sqlalchemy import NullPool
import pandas as pd

SelfClickHouseConnection = TypeVar("SelfClickHouseConnection", bound="ClickHouseConnection")

class ClickHouseConnection:
    """Класс контекстного менеджера для работы с ClickHouse"""
    
    def __init__(self, host: str, username: str, password: str, port: str = "9000"):
        """
        Параметры:
            host: хост ClickHouse
            username: имя пользователя ClickHouse
            password: пароль пользователя ClickHouse
            port: порт ClickHouse
        """
        
        self.session = None
        self.__host = host
        self.__port = port
        self.__username = username
        self.__password = password
        
    def __get_url(self) -> str:
        """Метод формирует connection string для подключения к ClickHouse"""
        
        url = "clickhouse+native://{username}:{password}@{host}:{port}"
        url = url.format(
            host = self.__host,
            port = self.__port,
            username = self.__username,
            password = self.__password
        )
        return url
        
    def __enter__(self: SelfClickHouseConnection) -> SelfClickHouseConnection:
        engine = sa.create_engine(self.__get_url(), poolclass=NullPool)
        self.session = engine.connect()
        return self
    
    def __exit__(self, exception_type, exception_value, traceback):
        self.session.close()
        
    def read_sql(self, query: str) -> pd.DataFrame:
        """
        Запрос к БД через фреймворк pandas
        
        Параметры:
            query: SQL в формате строки
            
        Возвращает:
            датафрейм с результатами запроса
        """
        
        with self as connector:
            return pd.read_sql(query, con=connector.session)

# %%
ch_host = "10.120.1.11"
ch_port = 8123
ch_username = "amarbuliev"
ch_password = "KuUNgVlPQiSN6dRqk"

connection_manager = ClickHouseConnection(host=ch_host, username=ch_username, password=ch_password)
df = connection_manager.read_sql("SELECT * FROM sandbox.ongoing_projects")

# %%
df.head()
# Out:
#    id          status statusDesc                         nameRus  \
# 0  11  control_passed    Рабочий                  Smart медицина
# 1  17  control_passed    Рабочий      Оснащение Медиацентра МИЭМ
# 2  20  control_passed    Рабочий  Система бронирования аудиторий
# 3  21  control_passed    Рабочий      Mekstack: приватное облако
# 4  24  control_passed    Рабочий              Цифровое портфолио
#
#                               head                    directionHead  \
# 0           Фимина Ксения Игоревна     Белов Александр Владимирович
# 1      Елисеенко Андрей Михайлович      Королев Денис Александрович
# 2        Рыбаков Петр Владимирович        Рыбаков Петр Владимирович
# 3  Емельяненко Максим Владимирович        Рыбаков Петр Владимирович
# 4  Сластников Сергей Александрович  Сластников Сергей Александрович
#
#         type    typeDesc  typeId  statusId  ... payed  projectOfficeControl  \
# 0       soft  Неизвестно       2         2  ...  True                  True
# 1  soft-hard  Неизвестно       3         2  ...  True                  True
# 2       soft  Неизвестно       2         2  ...  True                  True
# 3       soft  Неизвестно       2         2  ...  True                  True
# 4       soft  Неизвестно       2         2  ...  True                  True
#
#   studentsCount                                       searchString  \
# 0             5  Фимина Ксения Игоревна 19058 Smart медицина Па...
# 1             4  Елисеенко Андрей Михайлович 19102 Оснащение Ме...
# 2             2  Рыбаков Петр Владимирович 19105 Система бронир...
# 3            15  Емельяненко Максим Владимирович 19106 Mekstack...
# 4             1  Сластников Сергей Александрович 19109 Цифровое...
#
#    clientLogo                                      detailed_team  \
# 0              [{'fullName': 'Гончаров Никита Павлович', 'nam...
# 1              [{'fullName': 'Асташов Степан Дмитриевич', 'na...
# 2              [{'fullName': 'Мартинич Андрей Иванович', 'nam...
# 3              [{'fullName': 'Автайкин Артём Олегович', 'name...
# 4              [{'fullName': 'Дырченкова Юлия Александровна',...
#
#   projectIndustryLabel                                            leaders  \
# 0      Здравоохранение  [{'id': 67, 'fio': 'Фимина Ксения Игоревна', '...
# 1                  ИКТ  [{'id': 633, 'fio': 'Елисеенко Андрей Михайлов...
# 2                  ИКТ  [{'id': 55, 'fio': 'Рыбаков Петр Владимирович'...
# 3                  ИКТ  [{'id': 1734, 'fio': 'Емельяненко Максим Влади...
# 4           Неизвестно  [{'id': 62, 'fio': 'Сластников Сергей Александ...
#
#    initiatorId                                         thumbnail
# 0         67.0                                               nan
# 1          NaN                                               nan
# 2          NaN                                               nan
# 3          NaN  https://cabinet.miem.hse.ru/project/thumbnail/21
# 4          NaN                                               nan
#
# [5 rows x 27 columns]
