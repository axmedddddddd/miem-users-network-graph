# %%
from typing import TypeVar
import sqlalchemy as sa
from sqlalchemy import NullPool
import pandas as pd

SelfClickHouseConnection = TypeVar("SelfClickHouseConnection", bound="ClickHouseConnection")

class ClickHouseConnection:
    """Класс контекстного менеджера для работы с ClickHouse"""
    
    def __init__(self, host: str, username: str, password: str, port: str = "9000"):
        """
        Параметры:
            host: хост ClickHouse
            username: имя пользователя ClickHouse
            password: пароль пользователя ClickHouse
            port: порт ClickHouse
        """
        
        self.session = None
        self.__host = host
        self.__port = port
        self.__username = username
        self.__password = password
        
    def __get_url(self) -> str:
        """Метод формирует connection string для подключения к ClickHouse"""
        
        url = "clickhouse+native://{username}:{password}@{host}:{port}"
        url = url.format(
            host = self.__host,
            port = self.__port,
            username = self.__username,
            password = self.__password
        )
        return url
        
    def __enter__(self: SelfClickHouseConnection) -> SelfClickHouseConnection:
        engine = sa.create_engine(self.__get_url(), poolclass=NullPool)
        self.session = engine.connect()
        return self
    
    def __exit__(self, exception_type, exception_value, traceback):
        self.session.close()
        
    def read_sql(self, query: str) -> pd.DataFrame:
        """
        Запрос к БД через фреймворк pandas
        
        Параметры:
            query: SQL в формате строки
            
        Возвращает:
            датафрейм с результатами запроса
        """
        
        with self as connector:
            return pd.read_sql(query, con=connector.session)

# %%
ch_host = "10.120.1.11"
ch_port = 8123
ch_username = "amarbuliev"
ch_password = "KuUNgVlPQiSN6dRqk"

connection_manager = ClickHouseConnection(host=ch_host, username=ch_username, password=ch_password)

df = connection_manager.read_sql("SELECT * FROM sandbox.ongoing_projects")

# %%
df.leaders[0]
# Out:
# "[{'id': 67, 'fio': 'Фимина Ксения Игоревна', 'name': 'Фимина Ксения Игоревна', 'first_name': 'Ксения', 'last_name': 'Фимина', 'middle_name': 'Игоревна', 'email': ['kfimina@hse.ru'], 'telnum': None, 'ownerPrivilege': 1, 'status': [{'id': 1, 'code': 'project_leader', 'name': 'Руководитель проекта'}, {'id': 5, 'code': 'initiator', 'name': 'Инициатор проекта'}], 'role': 'Руководитель проекта, Инициатор проекта'}, {'id': 8, 'fio': 'Белов Александр Владимирович', 'name': 'Белов Александр Владимирович', 'first_name': 'Александр', 'last_name': 'Белов', 'middle_name': 'Владимирович', 'email': ['AVBelov@hse.ru'], 'telnum': None, 'ownerPrivilege': 1, 'status': [{'id': 2, 'code': 'direction_leader', 'name': 'Руководитель направления'}], 'role': 'Руководитель направления'}]"

# %%
import ast

def extract_email_prefixes_and_short_names(df, column_name='leaders'):
    """
    Extract email prefixes and short names from DataFrame based on a specific column containing leaders' information.
    """
    result_dict = {}
    for row in df[column_name]:
        leader_list = ast.literal_eval(row)
        for leader in leader_list:
            # Construct short_name
            short_name = f"{leader['last_name']}"
            if leader["middle_name"] and leader["first_name"]:
                short_name = f"{leader['last_name']} {leader['first_name'][0]}.{leader['middle_name'][0]}."
            elif leader["first_name"]:
                short_name = f"{leader['last_name']} {leader['first_name'][0]}."

            # Extract email
            email = leader.get('email')
            if isinstance(email, list) and email:  # If email is a non-empty list
                first_email = email[0]  # Take the first item
            elif isinstance(email, str):  # If email is already a string
                first_email = email
            else:  # If there is no email or it's not in an expected format
                first_email = None
            
            # Process email to get email prefix
            if first_email:
                email_prefix = first_email.split('@')[0]
            else:  # Handle cases with no valid email
                email_prefix = None
            
            # Update result dictionary with a tuple containing the email prefix and the short name
            result_dict[leader['id']] = (email_prefix, short_name)

    return result_dict

# %%
extract_email_prefixes_and_short_names(df)
# Out:
# {67: ('kfimina', 'Фимина К.И.'),
#  8: ('AVBelov', 'Белов А.В.'),
#  633: ('ameliseenko', 'Елисеенко А.М.'),
#  33: ('dkorolev', 'Королев Д.А.'),
#  0: (None, ''),
#  55: ('prybakov', 'Рыбаков П.В.'),
#  1734: ('mvemelyanenko', 'Емельяненко М.В.'),
#  62: ('sslastnikov', 'Сластников С.А.'),
#  4089: ('va.shin', 'Шин В.А.'),
#  7: ('vbashun', 'Башун В.В.'),
#  2305: ('daabramov_2', 'Абрамов Д.А.'),
#  1980: ('isemichasnov', 'Семичаснов И.В.'),
#  1385: ('mvmoiseev', 'Моисеев М.В.'),
#  1052: ('aamerikanov', 'Американов А.А.'),
#  53: ('a.romanov', 'Романов А.Ю.'),
#  51: ('npugach', 'Пугач Н.Г.'),
#  676: ('adpiskunov', 'Пискунов А.Д.'),
#  749: ('amzayakina', 'Пискунова А.М.'),
#  631: ('asyuldashov', 'Юлдашов А.С.'),
#  626: ('vburov', 'Буров В.В.'),
#  52: ('arolich', 'Ролич А.Ю.'),
#  32: ('ikarpova', 'Карпова И.П.'),
#  63: ('vstarykh', 'Старых В.А.'),
#  30: ('i.ivanov', 'Иванов И.А.'),
#  41: ('vminchenkov', 'Минченков В.О.'),
#  60: ('avsergeev', 'Сергеев А.В.'),
#  1884: ('adkasatkin', 'Касаткин А.Д.'),
#  1899: ('vmikolaenko', 'Миколаенко В.В.'),
#  3: ('saksenov', 'Аксенов С.А.'),
#  2243: ('akamkin', 'Камкин А.С.'),
#  9: ('mvbelova', 'Белова М.В.'),
#  48: ('spolessky', 'Полесский С.Н.'),
#  15: ('lvoskov', 'Восков Л.С.'),
#  23: ('vgdanilov', 'Данилов В.Г.'),
#  2216: ('vsmakshanchikov', 'Макшанчиков В.С.'),
#  377: ('aasapozhnikov', 'Сапожников А.А.'),
#  3771: ('vg.stepanyants', 'Степанянц В.Г.'),
#  29: ('yzontov', 'Зонтов Ю.В.'),
#  530: ('imotajlenko', 'Мотайленко И.А.'),
#  2563: ('aistratov', 'Истратов А.Ю.'),
#  2736: ('yudenisov', 'Денисов Ю.'),
#  2841: ('takurmasheva', 'Курмашева Т.А.'),
#  14: ('avarnavsky', 'Варнавский А.Н.'),
#  495: ('ikharitonov', 'Харитонов И.А.'),
#  34: ('pskorolev', 'Королев П.С.'),
#  646: ('sbalakin', 'Балакин С.В.'),
#  66: ('STumkovskiy', 'Тумковский С.Р.'),
#  2045: ('vonikitin', 'Никитин В.О.'),
#  1994: ('aakulishenko', 'Кулишенко А.А.'),
#  3533: ('nsbazhov', 'Бажов Н.С.'),
#  2574: ('evportnova', 'Портнова Е.В.'),
#  558: ('elezhnev', 'Лежнев Е.В.'),
#  3775: ('rruziev', 'Рузиев Р.И.'),
#  2268: ('yaamazikov', 'Мазиков Я.А.'),
#  2670: ('vzunin', 'Зунин В.В.'),
#  1697: ('ymeshcheryakov', 'Мещеряков Я.Е.'),
#  618: ('syakimenko', 'Якименко С.И.'),
#  745: ('asorokin', 'Сорокин А.В.'),
#  47: ('bpozin', 'Позин Б.А.'),
#  3166: ('orogacheva', 'Рогачева О.А.'),
#  1397: ('akiryushina', 'Кирюшина А.А.'),
#  493: ('lshchur', 'Щур Л.Н.'),
#  2828: ('gprudak', 'Рудак Г.П.'),
#  2776: ('aaganichev', 'Ганичев А.А.'),
#  3304: ('snikitin', 'Никитин С.Е.'),
#  3359: ('sportnoy', 'Портной С.Л.'),
#  3430: ('vgromov', 'Громов В.А.'),
#  3584: ('vsheikin', 'Шейкин В.'),
#  2481: ('vmironkin', 'Миронкин В.О.'),
#  2997: ('pkkryzhanovskiy', 'Крыжановский П.К.'),
#  3564: ('pgridchina', 'Гридчина П.'),
#  49: ('da.popov', 'Попов Д.А.'),
#  40: ('lmanita', 'Манита Л.А.'),
#  5: ('vafanasiev', 'Афанасьев В.Н.'),
#  3568: ('vamolchanova_2', 'Молчанова В.А.'),
#  2648: ('smaltseva', 'Мальцева С.В.'),
#  1047: ('dfomin', 'Фомин Д.Б.'),
#  1676: ('apodshivalov', 'Подшивалов А.А.'),
#  2698: ('aujmin', 'Уймин А.Г.'),
#  1098: ('ddemin', 'Дёмин Д.О.'),
#  68: ('pshnurkov', 'Шнурков П.В.'),
#  2611: ('snsukharnikov', 'Сухарников С.Н.'),
#  18: ('agolubin', 'Голубин А.Ю.'),
#  31: ('fivanov', 'Иванов Ф.И.'),
#  1929: ('pkostenetskiy', 'Костенецкий П.С.'),
#  44: ('rozhegov', 'Ожегов Р.В.'),
#  651: ('ivpostnikov', 'Постников И.В.'),
#  573: ('rsnovikov', 'Новиков Р.С.'),
#  36: ('mkrasivskaya', 'Красивская М.И.'),
#  4027: ('lchashkin', 'Чашкин Л.Б.'),
#  50: ('eprokofyeva', 'Прокофьева Е.Н.'),
#  2015: ('fazakharov_1', 'Захаров Ф.А.'),
#  648: ('ngrachev', 'Грачев Н.Н.'),
#  667: ('avasenko', 'Васенко А.С.'),
#  662: ('rihsanov', 'Ихсанов Р.Ш.'),
#  3246: ('dlyu', 'Лю Д.'),
#  1601: ('atuv', 'Тув А.Л.'),
#  2310: ('eamagid', 'Магид Е.'),
#  3930: ('askukharenko', 'Кухаренко А.С.'),
#  1723: ('rzheltov', 'Желтов Р.Л.'),
#  1267: ('mkozhukhov', 'Кожухов М.В.'),
#  3949: ('atarakanov', 'Тараканов А.А.'),
#  64: ('ostukach', 'Стукач О.В.'),
#  3947: ('dsilkin', 'Силкин Д.С.'),
#  3079: ('vkovalyuk', 'Ковалюк В.В.'),
#  3965: ('khanotel', 'Ханотел П.К.'),
#  1837: ('gsmirnov', 'Смирнов Г.С.'),
#  2001: ('mbubnova', 'Бубнова М.А.'),
#  2049: ('snefedov', 'Нефедов С.И.'),
#  2153: ('dmbobrova', 'Боброва Д.М.'),
#  849: ('damazur', 'Мазур Д.А.'),
#  1: ('AAbrameshin', 'Абрамешин А.Е.'),
#  3550: ('aakovalenko', 'Коваленко А.А.'),
#  2306: ('vashin', 'Шин В.А.'),
#  1028: ('aosemenov_1', 'Семенов А.О.'),
#  2530: ('ilubashevskii', 'Лубашевский И.А.'),
#  1231: ('nasavelev_3', 'Савельев Н.А.'),
#  403: ('gastreltsov', 'Стрельцов Г.А.'),
#  3186: ('gsbaydin', 'Байдин Г.С.'),
#  1801: ('ekrouk', 'Крук Е.А.'),
#  4234: ('einabiev', 'Набиев Э.И.'),
#  1176: ('vpisarev', 'Писарев В.В.'),
#  3991: ('melezov', 'Елезов М.С.'),
#  2: ('dabrameshin', 'Абрамешин Д.А.'),
#  557: ('karutyunov', 'Арутюнов К.Ю.'),
#  65: ('ntrubochkina', 'Трубочкина Н.К.'),
#  28: ('izahariev', 'Захарьев И.Ю.'),
#  4015: ('akaperko', 'Каперко А.Ф.'),
#  3087: ('dnzheltova', 'Желтова Д.Н.'),
#  4084: ('borekhov', 'Орехов Б.В.'),
#  3414: ('eklyshinsky', 'Клышинский Э.С.'),
#  2462: ('vakrepker', 'Крепкер В.А.'),
#  4137: ('vimorozov', 'Морозов В.И.'),
#  645: ('gdenisova', 'Смирнова Г.А.'),
#  1262: ('grishunina', 'Гришунина Ю.Б.'),
#  4141: ('mshulgin', 'Шульгин М.А.'),
#  1809: ('anesterenko', 'Нестеренко А.Ю.'),
#  1599: ('yukochetkov', 'Кочетков Ю.Ю.'),
#  3136: ('pmbochkarev', 'Бочкарев П.М.'),
#  2133: ('mulubay', 'Улубай М.'),
#  197: ('avkalyagin', 'Калягин А.В.'),
#  3482: ('a.dmitriev', 'Дмитриев А.В.'),
#  10: ('sbober', 'Бобер С.А.'),
#  3383: ('aamotyakin', 'Мотякин А.А.'),
#  4145: ('is.timokhin', 'Тимохин И.С.'),
#  2354: ('ivkuznetsov_1', 'Кузнецов И.В.'),
#  2208: ('dbashinskiy', 'Башинский Д.'),
#  926: ('ndkuznetsov_1', 'Кузнецов Н.Д.'),
#  2195: ('arfakhretdinov_1', 'Фахретдинов А.Р.'),
#  4217: ('igorbunov', 'Горбунов И.И.'),
#  146: ('iigorbunov', 'Горбунов И.И.'),
#  896: ('dochuyko', 'Чуйко Д.О.'),
#  561: ('emivanova', 'Иванова Е.М.'),
#  993: ('alerner', 'Лернер А.'),
#  1271: ('povolkov', 'Волков П.О.'),
#  59: ('asemion', 'Семион А.А.'),
#  4202: ('mapuchin', 'Пучин М.А.'),
#  1695: ('aanashkin', 'Анашкин А.В.'),
#  1859: ('imonakhov', 'Монахов И.С.'),
#  2967: ('arerofeeva', 'Ерофеева А.Р.'),
#  3405: ('vsbukina', 'Букина В.С.'),
#  2345: ('lzotov', 'Зотов Л.В.'),
#  695: ('rkbadalyan', 'Бадалян Р.К.'),
#  2534: ('vnemna', 'Немна В.А.'),
#  4269: ('vstarostenko', 'Старостенко В.И.'),
#  1550: ('vburmistrov', 'Бурмистров В.'),
#  1525: ('ssalibekyan', 'Салибекян С.М.'),
#  4301: ('inmanyakin', 'Илья М.'),
#  2278: ('apkrechetov', 'Кречетов А.П.'),
#  2887: ('okkravtseva', 'Кравцева О.К.')}
